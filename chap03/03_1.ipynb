# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.2.54-cp38-cp38-win_amd64.whl (34.7 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\anmin\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.2.54
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade tensorflow==2.5.0
# Out:
# Collecting tensorflow==2.5.0
#   Downloading tensorflow-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Requirement already satisfied, skipping upgrade: wheel~=0.35 in c:\users\anmin\anaconda3\lib\site-packages (from tensorflow==2.5.0) (0.35.1)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.17.3-py2.py3-none-any.whl (173 kB)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied, skipping upgrade: numpy~=1.19.2 in c:\users\anmin\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.19.2)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in c:\users\anmin\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.15.0)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Requirement already satisfied, skipping upgrade: typing-extensions~=3.7.4 in c:\users\anmin\anaconda3\lib\site-packages (from tensorflow==2.5.0) (3.7.4.3)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.30.2-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\users\anmin\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.24.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\anmin\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.0.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in c:\users\anmin\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (50.3.1.post20201107)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\anmin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\anmin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.25.11)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\anmin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\anmin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.10)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Building wheels for collected packages: wrapt, termcolor
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19558 sha256=29cae466ca8f64a0ddf522647008a6e7395357e09f0c1af44fed875f9c06daf8
#   Stored in directory: c:\users\anmin\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=da55f10117f331585d10649d3347ef65ee98c813397bf7f5586de31da2657407
#   Stored in directory: c:\users\anmin\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built wrapt termcolor
# Installing collected packages: wrapt, absl-py, flatbuffers, astunparse, cachetools, pyasn1, rsa, pyasn1-modules, google-auth, grpcio, tensorboard-plugin-wit, protobuf, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-data-server, markdown, tensorboard, termcolor, keras-preprocessing, keras-nightly, h5py, tensorflow-estimator, opt-einsum, gast, google-pasta, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# Successfully installed absl-py-0.12.0 astunparse-1.6.3 cachetools-4.2.2 flatbuffers-1.12 gast-0.4.0 google-auth-1.30.2 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 wrapt-1.12.1

# %%
# !pip install --upgrade keras==2.1.4
# Out:
# Requirement already up-to-date: keras==2.1.4 in c:\users\anmin\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in c:\users\anmin\anaconda3\lib\site-packages (from keras==2.1.4) (1.15.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in c:\users\anmin\anaconda3\lib\site-packages (from keras==2.1.4) (1.5.2)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\anmin\anaconda3\lib\site-packages (from keras==2.1.4) (5.3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in c:\users\anmin\anaconda3\lib\site-packages (from keras==2.1.4) (1.19.2)

# %%
import cv2

# %%
import urllib.request as req
url = "http://uta.pw/shodou/img/28/214.png"
req.urlretrieve(url, "test.png")
# Out:
# ('test.png', <http.client.HTTPMessage at 0x15396f17f10>)

# %%
img = cv2.imread('test.png')
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import cv2
img =

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread('test.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
im2 = cv2.resize(img, (600, 300))
cv2.imwrite('out-resize.png', im2)
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img = cv2.imread('test.png')
im2 = img[450:, 0:100]

im2 = cv2.resize(im2, (400, 400))
cv2.imwrite('cut-resize.png', im2)
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()
